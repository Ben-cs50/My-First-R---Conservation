# %% [markdown]
# # Analysis of "Wild Tomorrow Survey Responses"

# %% [markdown]
# Importing the required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the pre and post survey data
pre_data = pd.read_csv('Wild Tomorrow Survey Responses - Pre-Survey.csv')
post_data = pd.read_csv('Wild Tomorrow Survey Responses - Pre-Survey.csv')

# %%
# Showing the shape of our data
pre_data.shape
# Out:
# (21, 23)

# %%
post_data.shape
# Out:
# (21, 23)

# %%
# Top 10 data in pre_data
pre_data.head()
# Out:
#   School or Organisation Name Community Name       Country  \
# 0       Hambanathi EC Charity          Mduku  South Africa
# 1       Hambanathi EC Charity          Mduku  South Africa
# 2       Hambanathi EC Charity          Mduku  South Africa
# 3       Hambanathi EC Charity          Mduku  South Africa
# 4       Hambanathi EC Charity          Mduku  South Africa
#
#   Learner Name and Surname  Learner Age Gender  \
# 0             Dube Samkelo         11.0   Male
# 1               Nkosikhona         10.0   Male
# 2        Banele Mngomezulu         10.0   Male
# 3       Sakhile Mngomezulu         12.0   Male
# 4          Andile Dumakude         14.0   Male
#
#   Have you learned about Conservation? Have you seen animals in the wild?  \
# 0                                   No                                 No
# 1                                   No                                 No
# 2                                   No                                 No
# 3                                   No                                 No
# 4                                   No                                 No
#
#   Does the Earth need our help? What is your favourite animal?  ...  \
# 0                           Yes                       Elephant  ...
# 1                           NaN                              1  ...
# 2                           NaN                           Lion  ...
# 3                           Yes                           Lion  ...
# 4                            No                           Lion  ...
#
#                 What is conservation? Correctness of answer  \
# 0  The conservation is a day animals.             Incorrect
# 1                                 NaN             Incorrect
# 2                           Con vtion             Incorrect
# 3                        Conservation             Incorrect
# 4                                 Yes             Incorrect
#
#   Is it good to kill snakes?          Given Reason  \
# 0                         No  No you will animals.
# 1                        NaN                   NaN
# 2                        NaN              Cha bcos
# 3                        Yes           Yes because
# 4                         No     No because of one
#
#               Reason Category                           What is an ecosystem?  \
# 0  Aware of conservation value  Living and non-living things working together
# 1                          NaN                         Animals having a party
# 2                Unfamiliarity  Living and non-living things working together
# 3                Unfamiliarity  Living and non-living things working together
# 4                Unfamiliarity  Living and non-living things working together
#
#   Correctness of Answer Do you think that animals work as a team?  \
# 0               Correct                                       Yes
# 1             Incorrect                                        No
# 2               Correct                                       Yes
# 3               Correct                                        No
# 4               Correct                                       Yes
#
#   Is conservation important for people? Is it good to kill insects?
# 0                                    No                          No
# 1                                   NaN                         NaN
# 2                                   Yes                          No
# 3                                   Yes                          No
# 4                                   Yes                         Yes
#
# [5 rows x 23 columns]

# %%
# Top 10 data in pre_data
post_data.head()
# Out:
#   School or Organisation Name Community Name       Country  \
# 0       Hambanathi EC Charity          Mduku  South Africa
# 1       Hambanathi EC Charity          Mduku  South Africa
# 2       Hambanathi EC Charity          Mduku  South Africa
# 3       Hambanathi EC Charity          Mduku  South Africa
# 4       Hambanathi EC Charity          Mduku  South Africa
#
#   Learner Name and Surname  Learner Age Gender  \
# 0             Dube Samkelo         11.0   Male
# 1               Nkosikhona         10.0   Male
# 2        Banele Mngomezulu         10.0   Male
# 3       Sakhile Mngomezulu         12.0   Male
# 4          Andile Dumakude         14.0   Male
#
#   Have you learned about Conservation? Have you seen animals in the wild?  \
# 0                                   No                                 No
# 1                                   No                                 No
# 2                                   No                                 No
# 3                                   No                                 No
# 4                                   No                                 No
#
#   Does the Earth need our help? What is your favourite animal?  ...  \
# 0                           Yes                       Elephant  ...
# 1                           NaN                              1  ...
# 2                           NaN                           Lion  ...
# 3                           Yes                           Lion  ...
# 4                            No                           Lion  ...
#
#                 What is conservation? Correctness of answer  \
# 0  The conservation is a day animals.             Incorrect
# 1                                 NaN             Incorrect
# 2                           Con vtion             Incorrect
# 3                        Conservation             Incorrect
# 4                                 Yes             Incorrect
#
#   Is it good to kill snakes?          Given Reason  \
# 0                         No  No you will animals.
# 1                        NaN                   NaN
# 2                        NaN              Cha bcos
# 3                        Yes           Yes because
# 4                         No     No because of one
#
#               Reason Category                           What is an ecosystem?  \
# 0  Aware of conservation value  Living and non-living things working together
# 1                          NaN                         Animals having a party
# 2                Unfamiliarity  Living and non-living things working together
# 3                Unfamiliarity  Living and non-living things working together
# 4                Unfamiliarity  Living and non-living things working together
#
#   Correctness of Answer Do you think that animals work as a team?  \
# 0               Correct                                       Yes
# 1             Incorrect                                        No
# 2               Correct                                       Yes
# 3               Correct                                        No
# 4               Correct                                       Yes
#
#   Is conservation important for people? Is it good to kill insects?
# 0                                    No                          No
# 1                                   NaN                         NaN
# 2                                   Yes                          No
# 3                                   Yes                          No
# 4                                   Yes                         Yes
#
# [5 rows x 23 columns]

# %%
# Displaying duplicate entries
pre_data_duplicate = pre_data[pre_data.duplicated()]
pre_data_duplicate
# Out:
# Empty DataFrame
# Columns: [School or Organisation Name, Community Name, Country, Learner Name and Surname, Learner Age, Gender, Have you learned about Conservation?, Have you seen animals in the wild?, Does the Earth need our help?, What is your favourite animal?, Favourite Animal Type, What job do you want one day?, General Job Industry, What is conservation?, Correctness of answer, Is it good to kill snakes?, Given Reason, Reason Category , What is an ecosystem?, Correctness of Answer, Do you think that animals work as a team?, Is conservation important for people?, Is it good to kill insects?]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Displaying duplicate entries
post_data_duplicate = post_data[post_data.duplicated()]
post_data_duplicate
# Out:
# Empty DataFrame
# Columns: [School or Organisation Name, Community Name, Country, Learner Name and Surname, Learner Age, Gender, Have you learned about Conservation?, Have you seen animals in the wild?, Does the Earth need our help?, What is your favourite animal?, Favourite Animal Type, What job do you want one day?, General Job Industry, What is conservation?, Correctness of answer, Is it good to kill snakes?, Given Reason, Reason Category , What is an ecosystem?, Correctness of Answer, Do you think that animals work as a team?, Is conservation important for people?, Is it good to kill insects?]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# This shows that we do not have duplicated rows

# %%
# Cheking the total missing values
pre_data_missing = pre_data.isna().sum()
pre_data_missing
# Out:
# School or Organisation Name                  0
# Community Name                               0
# Country                                      0
# Learner Name and Surname                     0
# Learner Age                                  1
# Gender                                       2
# Have you learned about Conservation?         0
# Have you seen animals in the wild?           0
# Does the Earth need our help?                2
# What is your favourite animal?               0
# Favourite Animal Type                        2
# What job do you want one day?                1
# General Job Industry                         3
# What is conservation?                        1
# Correctness of answer                        0
# Is it good to kill snakes?                   5
# Given Reason                                 1
# Reason Category                              2
# What is an ecosystem?                        0
# Correctness of Answer                        0
# Do you think that animals work as a team?    0
# Is conservation important for people?        1
# Is it good to kill insects?                  1
# dtype: int64

# %%
# Cheking the total missing values
post_data_missing = post_data.isna().sum()
post_data_missing
# Out:
# School or Organisation Name                  0
# Community Name                               0
# Country                                      0
# Learner Name and Surname                     0
# Learner Age                                  1
# Gender                                       2
# Have you learned about Conservation?         0
# Have you seen animals in the wild?           0
# Does the Earth need our help?                2
# What is your favourite animal?               0
# Favourite Animal Type                        2
# What job do you want one day?                1
# General Job Industry                         3
# What is conservation?                        1
# Correctness of answer                        0
# Is it good to kill snakes?                   5
# Given Reason                                 1
# Reason Category                              2
# What is an ecosystem?                        0
# Correctness of Answer                        0
# Do you think that animals work as a team?    0
# Is conservation important for people?        1
# Is it good to kill insects?                  1
# dtype: int64

# %%
# Handling missing values by droping
pre_data = pre_data.dropna()
post_data = post_data.dropna()

# %% [markdown]
# Checking for missing values again

# %%
# Checking missing values for pre-survey
pre_data_missing_after = pre_data.isna().sum()
pre_data_missing_after
# Out:
# School or Organisation Name                  0
# Community Name                               0
# Country                                      0
# Learner Name and Surname                     0
# Learner Age                                  0
# Gender                                       0
# Have you learned about Conservation?         0
# Have you seen animals in the wild?           0
# Does the Earth need our help?                0
# What is your favourite animal?               0
# Favourite Animal Type                        0
# What job do you want one day?                0
# General Job Industry                         0
# What is conservation?                        0
# Correctness of answer                        0
# Is it good to kill snakes?                   0
# Given Reason                                 0
# Reason Category                              0
# What is an ecosystem?                        0
# Correctness of Answer                        0
# Do you think that animals work as a team?    0
# Is conservation important for people?        0
# Is it good to kill insects?                  0
# dtype: int64

# %%
# Checking missing values for post-survey
post_data_missing_after = post_data.isna().sum()
post_data_missing_after
# Out:
# School or Organisation Name                  0
# Community Name                               0
# Country                                      0
# Learner Name and Surname                     0
# Learner Age                                  0
# Gender                                       0
# Have you learned about Conservation?         0
# Have you seen animals in the wild?           0
# Does the Earth need our help?                0
# What is your favourite animal?               0
# Favourite Animal Type                        0
# What job do you want one day?                0
# General Job Industry                         0
# What is conservation?                        0
# Correctness of answer                        0
# Is it good to kill snakes?                   0
# Given Reason                                 0
# Reason Category                              0
# What is an ecosystem?                        0
# Correctness of Answer                        0
# Do you think that animals work as a team?    0
# Is conservation important for people?        0
# Is it good to kill insects?                  0
# dtype: int64

# %% [markdown]
# This shows that we have successfuly droped all the missing values

# %%
# Showing the shape of our cleaned data
pre_data.shape
# Out:
# (13, 23)

# %%
pre_data
# Out:
#    School or Organisation Name Community Name       Country  \
# 0        Hambanathi EC Charity          Mduku  South Africa
# 3        Hambanathi EC Charity          Mduku  South Africa
# 4        Hambanathi EC Charity          Mduku  South Africa
# 6        Hambanathi EC Charity          Mduku  South Africa
# 8        Hambanathi EC Charity          Mduku  South Africa
# 9        Hambanathi EC Charity          Mduku  South Africa
# 10       Hambanathi EC Charity          Mduku  South Africa
# 11       Hambanathi EC Charity          Mduku  South Africa
# 13       Hambanathi EC Charity          Mduku  South Africa
# 14       Hambanathi EC Charity          Mduku  South Africa
# 15       Hambanathi EC Charity          Mduku  South Africa
# 16       Hambanathi EC Charity          Mduku  South Africa
# 17       Hambanathi EC Charity          Mduku  South Africa
#
#    Learner Name and Surname  Learner Age  Gender  \
# 0              Dube Samkelo         11.0    Male
# 3        Sakhile Mngomezulu         12.0    Male
# 4           Andile Dumakude         14.0    Male
# 6          Ndwandwe Alwande         12.0    Male
# 8        Sibonelo Buthelezi         13.0    Male
# 9        Mathenjwa Simphiwe         12.0  Female
# 10         Aphiwe Hlongwane         12.0    Male
# 11           Fanele Ngubene         11.0  Female
# 13        Nonsindiso Mdluli         12.0  Female
# 14           Nomfundo Ngiba         14.0  Female
# 15        Zanhlahla Khumalo         14.0  Female
# 16     Magubane Nonhlancelo         12.0  Female
# 17           Zothani Ndlovu         12.0  Female
#
#    Have you learned about Conservation? Have you seen animals in the wild?  \
# 0                                    No                                 No
# 3                                    No                                 No
# 4                                    No                                 No
# 6                                   Yes                                Yes
# 8                                   Yes                                Yes
# 9                                   Yes                                 No
# 10                                  Yes                                Yes
# 11                                  Yes                                Yes
# 13                                  Yes                                Yes
# 14                                  Yes                                Yes
# 15                                  Yes                                 No
# 16                                   No                                Yes
# 17                                   No                                Yes
#
#    Does the Earth need our help? What is your favourite animal?  ...  \
# 0                            Yes                       Elephant  ...
# 3                            Yes                           Lion  ...
# 4                             No                           Lion  ...
# 6                            Yes                       Elephant  ...
# 8                            Yes                           Lion  ...
# 9                             No                         Snakes  ...
# 10                           Yes                       Elephant  ...
# 11                           Yes                       Elephant  ...
# 13                           Yes                        Leopard  ...
# 14                           Yes                         Rabbit  ...
# 15                           Yes                           Lion  ...
# 16                           Yes                          Rhino  ...
# 17                            No                       Elephant  ...
#
#                                 What is conservation? Correctness of answer  \
# 0                  The conservation is a day animals.             Incorrect
# 3                                        Conservation             Incorrect
# 4                                                 Yes             Incorrect
# 6     We talk about to save nature to next generation               Correct
# 8   Conservation it is when we must protect or tak...               Correct
# 9                                 To help the animals               Correct
# 10  Is when we talk about saving nature for the ne...               Correct
# 11  Is to take care the nature from the next futur...               Correct
# 13  Conservation is protecting nature for the futu...               Correct
# 14  Is an area where we help our future and we con...               Correct
# 15  The care and protection resource for the curre...               Correct
# 16        It is taking care of the nature and animals               Correct
# 17                                 Do not kill animal             Incorrect
#
#    Is it good to kill snakes?  \
# 0                          No
# 3                         Yes
# 4                          No
# 6                          No
# 8                         Yes
# 9                          No
# 10                         No
# 11                         No
# 13                         No
# 14                         No
# 15                        Yes
# 16                         No
# 17                         No
#
#                                          Given Reason  \
# 0                                No you will animals.
# 3                                         Yes because
# 4                                   No because of one
# 6                     No because it fall under nature
# 8   Yes because they have no function they just bi...
# 9                       No because snakes is not good
# 10  No because the next generation should see and ...
# 11  No because the next future generation you must...
# 13  No it's not a good thing because snakes also h...
# 14           No because we need to save every animals
# 15                    Yes because snake will kill you
# 16         No because they are living their own lives
# 17           It not good to kill snakes is do nothing
#
#                Reason Category   \
# 0   Aware of conservation value
# 3                 Unfamiliarity
# 4                 Unfamiliarity
# 6   Aware of conservation value
# 8               Fear or disgust
# 9               Fear or disgust
# 10  Aware of conservation value
# 11  Aware of conservation value
# 13  Aware of conservation value
# 14  Aware of conservation value
# 15              Fear or disgust
# 16      Appreciation or respect
# 17      Appreciation or respect
#
#                             What is an ecosystem? Correctness of Answer  \
# 0   Living and non-living things working together               Correct
# 3   Living and non-living things working together               Correct
# 4   Living and non-living things working together               Correct
# 6   Living and non-living things working together               Correct
# 8   Living and non-living things working together               Correct
# 9   Living and non-living things working together               Correct
# 10  Living and non-living things working together               Correct
# 11  Living and non-living things working together               Correct
# 13  Living and non-living things working together               Correct
# 14  Living and non-living things working together               Correct
# 15                         Animals having a party             Incorrect
# 16  Living and non-living things working together               Correct
# 17  Living and non-living things working together               Correct
#
#    Do you think that animals work as a team?  \
# 0                                        Yes
# 3                                         No
# 4                                        Yes
# 6                                         No
# 8                                        Yes
# 9                                         No
# 10                                       Yes
# 11                                       Yes
# 13                                       Yes
# 14                                       Yes
# 15                                       Yes
# 16                                       Yes
# 17                                       Yes
#
#    Is conservation important for people? Is it good to kill insects?
# 0                                     No                          No
# 3                                    Yes                          No
# 4                                    Yes                         Yes
# 6                                    Yes                          No
# 8                                    Yes                          No
# 9                                    Yes                          No
# 10                                   Yes                          No
# 11                                   Yes                          No
# 13                                   Yes                          No
# 14                                   Yes                          No
# 15                                   Yes                          No
# 16                                   Yes                          No
# 17                                   Yes                          No
#
# [13 rows x 23 columns]

# %%
# Showing the shape of our cleaned data
post_data.shape
# Out:
# (13, 23)

# %%
post_data
# Out:
#    School or Organisation Name Community Name       Country  \
# 0        Hambanathi EC Charity          Mduku  South Africa
# 3        Hambanathi EC Charity          Mduku  South Africa
# 4        Hambanathi EC Charity          Mduku  South Africa
# 6        Hambanathi EC Charity          Mduku  South Africa
# 8        Hambanathi EC Charity          Mduku  South Africa
# 9        Hambanathi EC Charity          Mduku  South Africa
# 10       Hambanathi EC Charity          Mduku  South Africa
# 11       Hambanathi EC Charity          Mduku  South Africa
# 13       Hambanathi EC Charity          Mduku  South Africa
# 14       Hambanathi EC Charity          Mduku  South Africa
# 15       Hambanathi EC Charity          Mduku  South Africa
# 16       Hambanathi EC Charity          Mduku  South Africa
# 17       Hambanathi EC Charity          Mduku  South Africa
#
#    Learner Name and Surname  Learner Age  Gender  \
# 0              Dube Samkelo         11.0    Male
# 3        Sakhile Mngomezulu         12.0    Male
# 4           Andile Dumakude         14.0    Male
# 6          Ndwandwe Alwande         12.0    Male
# 8        Sibonelo Buthelezi         13.0    Male
# 9        Mathenjwa Simphiwe         12.0  Female
# 10         Aphiwe Hlongwane         12.0    Male
# 11           Fanele Ngubene         11.0  Female
# 13        Nonsindiso Mdluli         12.0  Female
# 14           Nomfundo Ngiba         14.0  Female
# 15        Zanhlahla Khumalo         14.0  Female
# 16     Magubane Nonhlancelo         12.0  Female
# 17           Zothani Ndlovu         12.0  Female
#
#    Have you learned about Conservation? Have you seen animals in the wild?  \
# 0                                    No                                 No
# 3                                    No                                 No
# 4                                    No                                 No
# 6                                   Yes                                Yes
# 8                                   Yes                                Yes
# 9                                   Yes                                 No
# 10                                  Yes                                Yes
# 11                                  Yes                                Yes
# 13                                  Yes                                Yes
# 14                                  Yes                                Yes
# 15                                  Yes                                 No
# 16                                   No                                Yes
# 17                                   No                                Yes
#
#    Does the Earth need our help? What is your favourite animal?  ...  \
# 0                            Yes                       Elephant  ...
# 3                            Yes                           Lion  ...
# 4                             No                           Lion  ...
# 6                            Yes                       Elephant  ...
# 8                            Yes                           Lion  ...
# 9                             No                         Snakes  ...
# 10                           Yes                       Elephant  ...
# 11                           Yes                       Elephant  ...
# 13                           Yes                        Leopard  ...
# 14                           Yes                         Rabbit  ...
# 15                           Yes                           Lion  ...
# 16                           Yes                          Rhino  ...
# 17                            No                       Elephant  ...
#
#                                 What is conservation? Correctness of answer  \
# 0                  The conservation is a day animals.             Incorrect
# 3                                        Conservation             Incorrect
# 4                                                 Yes             Incorrect
# 6     We talk about to save nature to next generation               Correct
# 8   Conservation it is when we must protect or tak...               Correct
# 9                                 To help the animals               Correct
# 10  Is when we talk about saving nature for the ne...               Correct
# 11  Is to take care the nature from the next futur...               Correct
# 13  Conservation is protecting nature for the futu...               Correct
# 14  Is an area where we help our future and we con...               Correct
# 15  The care and protection resource for the curre...               Correct
# 16        It is taking care of the nature and animals               Correct
# 17                                 Do not kill animal             Incorrect
#
#    Is it good to kill snakes?  \
# 0                          No
# 3                         Yes
# 4                          No
# 6                          No
# 8                         Yes
# 9                          No
# 10                         No
# 11                         No
# 13                         No
# 14                         No
# 15                        Yes
# 16                         No
# 17                         No
#
#                                          Given Reason  \
# 0                                No you will animals.
# 3                                         Yes because
# 4                                   No because of one
# 6                     No because it fall under nature
# 8   Yes because they have no function they just bi...
# 9                       No because snakes is not good
# 10  No because the next generation should see and ...
# 11  No because the next future generation you must...
# 13  No it's not a good thing because snakes also h...
# 14           No because we need to save every animals
# 15                    Yes because snake will kill you
# 16         No because they are living their own lives
# 17           It not good to kill snakes is do nothing
#
#                Reason Category   \
# 0   Aware of conservation value
# 3                 Unfamiliarity
# 4                 Unfamiliarity
# 6   Aware of conservation value
# 8               Fear or disgust
# 9               Fear or disgust
# 10  Aware of conservation value
# 11  Aware of conservation value
# 13  Aware of conservation value
# 14  Aware of conservation value
# 15              Fear or disgust
# 16      Appreciation or respect
# 17      Appreciation or respect
#
#                             What is an ecosystem? Correctness of Answer  \
# 0   Living and non-living things working together               Correct
# 3   Living and non-living things working together               Correct
# 4   Living and non-living things working together               Correct
# 6   Living and non-living things working together               Correct
# 8   Living and non-living things working together               Correct
# 9   Living and non-living things working together               Correct
# 10  Living and non-living things working together               Correct
# 11  Living and non-living things working together               Correct
# 13  Living and non-living things working together               Correct
# 14  Living and non-living things working together               Correct
# 15                         Animals having a party             Incorrect
# 16  Living and non-living things working together               Correct
# 17  Living and non-living things working together               Correct
#
#    Do you think that animals work as a team?  \
# 0                                        Yes
# 3                                         No
# 4                                        Yes
# 6                                         No
# 8                                        Yes
# 9                                         No
# 10                                       Yes
# 11                                       Yes
# 13                                       Yes
# 14                                       Yes
# 15                                       Yes
# 16                                       Yes
# 17                                       Yes
#
#    Is conservation important for people? Is it good to kill insects?
# 0                                     No                          No
# 3                                    Yes                          No
# 4                                    Yes                         Yes
# 6                                    Yes                          No
# 8                                    Yes                          No
# 9                                    Yes                          No
# 10                                   Yes                          No
# 11                                   Yes                          No
# 13                                   Yes                          No
# 14                                   Yes                          No
# 15                                   Yes                          No
# 16                                   Yes                          No
# 17                                   Yes                          No
#
# [13 rows x 23 columns]

# %%
# Selecting relevant columns
# Since the survey is done for South Africa Country, Mduku Community, and Hambanathi EC Charity School/Organisation
# We will not consider these fields
selected_pre_columns = ['Learner Age', 'Gender',
                    'Have you learned about Conservation?', 'Have you seen animals in the wild?',
                    'Does the Earth need our help?', 'What is your favourite animal?', 'What job do you want one day?',
                    'What is conservation?', 'What is an ecosystem?', 
                    'Is conservation important for people?', 'Is it good to kill insects?']

# Create a new DataFrame with selected columns
selected_pre_data = pre_data[selected_pre_columns]

# Display the first few rows of the selected data
print(selected_pre_data.head())
# Out:
#    Learner Age Gender Have you learned about Conservation?  \
# 0         11.0   Male                                   No
# 3         12.0   Male                                   No
# 4         14.0   Male                                   No
# 6         12.0   Male                                  Yes
# 8         13.0   Male                                  Yes
#
#   Have you seen animals in the wild? Does the Earth need our help?  \
# 0                                 No                           Yes
# 3                                 No                           Yes
# 4                                 No                            No
# 6                                Yes                           Yes
# 8                                Yes                           Yes
#
#   What is your favourite animal? What job do you want one day?  \
# 0                       Elephant                        Police
# 3                           Lion                        Police
# 4                           Lion                       English
# 6                       Elephant                        Doctor
# 8                           Lion                           Vet
#
#                                What is conservation?  \
# 0                 The conservation is a day animals.
# 3                                       Conservation
# 4                                                Yes
# 6    We talk about to save nature to next generation
# 8  Conservation it is when we must protect or tak...
#
#                            What is an ecosystem?  \
# 0  Living and non-living things working together
# 3  Living and non-living things working together
# 4  Living and non-living things working together
# 6  Living and non-living things working together
# 8  Living and non-living things working together
#
#   Is conservation important for people? Is it good to kill insects?
# 0                                    No                          No
# 3                                   Yes                          No
# 4                                   Yes                         Yes
# 6                                   Yes                          No
# 8                                   Yes                          No
